# %%
# !pip install soundfile
# Out:
# Requirement already satisfied: soundfile in /opt/conda/lib/python3.6/site-packages (0.10.2)
# Requirement already satisfied: cffi>=1.0 in /opt/conda/lib/python3.6/site-packages (from soundfile) (1.12.3)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.6/site-packages (from cffi>=1.0->soundfile) (2.19)

# %%
import os
import numpy as np
import pandas as pd
import soundfile as sf
import scipy.signal as signal
import matplotlib.pyplot as plt

# %%
train_path = '../input/train/train/'
test_path = '../input/test/test/'

# %%
filename = 'de_f_0809fd0642232f8c85b0b3d545dc2b5a.fragment1.flac'

# %%
data, samplerate = sf.read(train_path+filename)

# %%
data
# Out:
# array([-0.03903198, -0.03997803, -0.05319214, ..., -0.00836182,
#         0.01141357,  0.01940918])

# %%
freq, time, Sxx = signal.spectrogram(data, samplerate, scaling='spectrum')
plt.pcolormesh(time, freq, Sxx)

# add axis labels
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
# Out:
# Text(0.5, 0, 'Time [sec]')

# %%
Pxx, freqs, bins, im = plt.specgram(data, Fs=samplerate)

# add axis labels
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
# Out:
# Text(0.5, 0, 'Time [sec]')

# %%
data
# Out:
# array([-0.03903198, -0.03997803, -0.05319214, ..., -0.00836182,
#         0.01141357,  0.01940918])

# %%
plt.plot(data)
